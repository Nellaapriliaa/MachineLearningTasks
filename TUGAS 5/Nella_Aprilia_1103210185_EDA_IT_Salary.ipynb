# %% [markdown]
# <a href="https://colab.research.google.com/github/Nellaapriliaa/MachineLearningTasks/blob/main/TUGAS%205/Nella_Aprilia_1103210185_EDA_IT_Salary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama: Nella Aprilia
#
# NIM: 1103210185
#
# TUGAS 5: Exploratory Data Analysis (EDA IT Salary)
#
# Dokumentasi ChatGPT : https://chat.openai.com/share/cabe6598-133a-477f-a6cd-8cad83f489b8

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# 1. Masukan Library

# %% [markdown]
# beri kode untuk mount google drive ke google colab

# %%
from google.colab import drive

# Menghubungkan Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# 2. Data dari Google Drive

# %% [markdown]
# ChatGPT: Beri kode untuk read dataset as dataframe dengan path'/content/drive/MyDrive/Dataset/IT Salary Survey EU  2020.csv'

# %%
import pandas as pd

# Tentukan path dari dataset
file_path = '/content/drive/MyDrive/Dataset/IT Salary Survey EU  2020.csv'

# Baca dataset sebagai dataframe
df = pd.read_csv(file_path)

# Tampilkan dataframe
df.head()
# Out:
#              Timestamp   Age Gender    City           Position   \
# 0  24/11/2020 11:14:15  26.0   Male  Munich   Software Engineer
# 1  24/11/2020 11:14:16  26.0   Male  Berlin   Backend Developer
# 2  24/11/2020 11:14:21  29.0   Male  Berlin   Software Engineer
# 3  24/11/2020 11:15:24  28.0   Male  Berlin  Frontend Developer
# 4  24/11/2020 11:15:46  37.0   Male  Berlin   Backend Developer
#
#   Total years of experience Years of experience in Germany Seniority level  \
# 0                         5                              3          Senior
# 1                         7                              4          Senior
# 2                        12                              6            Lead
# 3                         4                              1          Junior
# 4                        17                              6          Senior
#
#   Your main technology / programming language  \
# 0                                  TypeScript
# ...

# %% [markdown]
# 3. Tampilan Data

# %%
df.tail()
# Out:
#                 Timestamp   Age Gender         City  \
# 1248  18/01/2021 15:05:50  31.0   Male       Berlin
# 1249  18/01/2021 17:46:02  33.0   Male       Berlin
# 1250  18/01/2021 23:20:35  39.0   Male       Munich
# 1251  19/01/2021 10:17:58  26.0   Male  Saarbrücken
# 1252  19/01/2021 12:01:11  26.0   Male       Berlin
#
#                                    Position  Total years of experience  \
# 1248                       Backend Developer                         9
# 1249  Researcher/ Consumer Insights Analyst                         10
# 1250                   IT Operations Manager                        15
# 1251                      Frontend Developer                         7
# 1252                                  DevOps                         2
#
#      Years of experience in Germany Seniority level  \
# 1248                              5          Senior
# 1249                            1.5          Senior
# 1250                              2            Lead
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1253 entries, 0 to 1252
# Data columns (total 23 columns):
#  #   Column                                                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                                                   --------------  -----
#  0   Timestamp                                                                                                                1253 non-null   object
#  1   Age                                                                                                                      1226 non-null   float64
#  2   Gender                                                                                                                   1243 non-null   object
# ...

# %% [markdown]
# ChatGPT Prompt: beri petunjuk untuk melakukan exploratory data analysis
#
# Exploratory Data Analysis (EDA) adalah proses untuk memahami dataset dengan melakukan analisis awal, visualisasi, dan pemahaman tentang karakteristik data. Berikut adalah beberapa langkah umum yang dapat ikuti saat melakukan EDA:
#
# **1. Memahami Data:**
# Baca dataset ke dalam DataFrame tinjau struktur data seperti jumlah baris dan kolom, serta tipe data setiap kolom. Tampilkan beberapa baris pertama dari DataFrame untuk mendapatkan gambaran awal tentang data.
#
# **2. Pembersihan Data:**
# Identifikasi dan tangani nilai-nilai yang hilang atau kosong. Tangani nilai-nilai yang tidak valid atau outliers.Konversikan tipe data jika diperlukan (misalnya, tanggal ke dalam format yang benar).
#
# **3. Analisis Univariat:**
# Analisis distribusi setiap fitur secara terpisah.Gunakan statistik deskriptif seperti mean, median, dan standar deviasi untuk mendapatkan pemahaman awal tentang data. Gunakan visualisasi seperti histogram, boxplot, atau density plot untuk memvisualisasikan distribusi data. Analisis Bivariat:
#
# **4. Analisis hubungan antara dua fitur.**
# Gunakan scatter plot untuk melihat hubungan antara dua variabel numerik.
# Gunakan heatmap untuk melihat korelasi antar variabel numerik. Gunakan bar plot atau box plot untuk melihat hubungan antara variabel kategorikal dan numerik.
#
# **5. Analisis Multivariat:**
# Analisis hubungan antara tiga atau lebih fitur secara bersamaan. Gunakan pair plot untuk melihat hubungan antara beberapa variabel numerik.Gunakan heatmap untuk melihat korelasi antar beberapa variabel numerik.
#
# **6. Pemahaman Domain:**
# Pertimbangkan pemahaman tentang domain Anda untuk menafsirkan hasil EDA dengan benar.Cari tahu apakah ada wawasan yang tidak diharapkan atau menarik yang ditemukan selama EDA.
#
# **7. Iterasi:**
# Lakukan iterasi melalui langkah-langkah EDA untuk mendapatkan pemahaman yang lebih baik tentang data.Tinjau temuan Anda dan tentukan langkah-langkah berikutnya berdasarkan temuan tersebut.
#
# **8. Dokumentasi:**
# Dokumentasikan langkah-langkah EDA Anda dengan jelas, baik dalam bentuk komentar di kode atau dalam laporan terpisah.Sertakan visualisasi dan temuan utama Anda.
#
# **9. Komunikasi Temuan:**
# Komunikasikan temuan Anda kepada stakeholder atau rekan tim dengan jelas dan efektif. Buat laporan atau presentasi untuk mempresentasikan temuan Anda dengan menggunakan visualisasi yang sesuai.

# %% [markdown]
# 4. Pengolahan Data

# %%
# Memilih kolom yang ingin ditampilkan
selected_features = ["Total years of experience",
                  "Years of experience in Germany",
                  "Yearly bonus + stocks in EUR",
                  "Annual bonus+stocks one year ago. Only answer if staying in same country",
                  "Number of vacation days",
                  "Contract duration" ,
                  "Company size"

]


# Menampilkan 5 baris teratas dari fitur-fitur tertentu
print(df.head())
# Out:
#              Timestamp   Age Gender    City           Position   \
# 0  24/11/2020 11:14:15  26.0   Male  Munich   Software Engineer
# 1  24/11/2020 11:14:16  26.0   Male  Berlin   Backend Developer
# 2  24/11/2020 11:14:21  29.0   Male  Berlin   Software Engineer
# 3  24/11/2020 11:15:24  28.0   Male  Berlin  Frontend Developer
# 4  24/11/2020 11:15:46  37.0   Male  Berlin   Backend Developer
#
#   Total years of experience Years of experience in Germany Seniority level  \
# 0                         5                              3          Senior
# 1                         7                              4          Senior
# 2                        12                              6            Lead
# 3                         4                              1          Junior
# 4                        17                              6          Senior
#
#   Your main technology / programming language  \
# 0                                  TypeScript
# ...

# %%
# Daftar fitur-fitur yang ingin diubah menjadi ke tipe data numerik
selected_features = ["Total years of experience",
                     "Years of experience in Germany",
                     "Yearly bonus + stocks in EUR",
                     "Annual bonus+stocks one year ago. Only answer if staying in same country",
                     "Number of vacation days"]

# Mengubah fitur-fitur menjadi tipe data numerik
df[selected_features] = df[selected_features].apply(pd.to_numeric, errors='coerce')

# Menampilkan hasil 5 baris dari fitur-fitur setelahn tipe datanya diubah
print("\nTipe datanya setelah diubah::")
print(df[selected_features].head())
# Out:
# Tipe datanya setelah diubah::
#    Total years of experience  Years of experience in Germany  \
# 0                        5.0                             3.0
# 1                        7.0                             4.0
# 2                       12.0                             6.0
# 3                        4.0                             1.0
# 4                       17.0                             6.0
#
#    Yearly bonus + stocks in EUR  \
# 0                        5000.0
# 1                           NaN
# 2                      120000.0
# 3                           NaN
# 4                           NaN
#
#    Annual bonus+stocks one year ago. Only answer if staying in same country  \
# 0                                            10000.0
# 1                                             5000.0
# 2                                           100000.0
# 3                                                NaN
# 4                                                NaN
#
# ...

# %%
df.head(7)
# Out:
#              Timestamp   Age Gender    City           Position   \
# 0  24/11/2020 11:14:15  26.0   Male  Munich   Software Engineer
# 1  24/11/2020 11:14:16  26.0   Male  Berlin   Backend Developer
# 2  24/11/2020 11:14:21  29.0   Male  Berlin   Software Engineer
# 3  24/11/2020 11:15:24  28.0   Male  Berlin  Frontend Developer
# 4  24/11/2020 11:15:46  37.0   Male  Berlin   Backend Developer
# 5  24/11/2020 11:15:53  32.0   Male  Berlin              DevOps
# 6  24/11/2020 11:16:35  37.0   Male  Berlin  Frontend Developer
#
#    Total years of experience  Years of experience in Germany Seniority level  \
# 0                        5.0                             3.0          Senior
# 1                        7.0                             4.0          Senior
# 2                       12.0                             6.0            Lead
# 3                        4.0                             1.0          Junior
# ...

# %%
df.tail(9)
# Out:
#                 Timestamp   Age Gender         City  \
# 1244  16/01/2021 22:23:04  32.0   Male       Munich
# 1245  17/01/2021 13:22:23  28.0   Male       Berlin
# 1246  18/01/2021 09:51:30  38.0   Male       Berlin
# 1247  18/01/2021 11:50:02  34.0   Male       Zurich
# 1248  18/01/2021 15:05:50  31.0   Male       Berlin
# 1249  18/01/2021 17:46:02  33.0   Male       Berlin
# 1250  18/01/2021 23:20:35  39.0   Male       Munich
# 1251  19/01/2021 10:17:58  26.0   Male  Saarbrücken
# 1252  19/01/2021 12:01:11  26.0   Male       Berlin
#
#                                    Position   Total years of experience  \
# 1244                       Software Engineer                       10.0
# 1245                      Frontend Developer                        5.0
# 1246                     Head of Engineering                       18.0
# 1247                       Software Engineer                        7.0
# 1248                       Backend Developer                        9.0
# ...

# %%
# Menampilkan informasi ringkas dari dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1253 entries, 0 to 1252
# Data columns (total 23 columns):
#  #   Column                                                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                                                   --------------  -----
#  0   Timestamp                                                                                                                1253 non-null   object
#  1   Age                                                                                                                      1226 non-null   float64
#  2   Gender                                                                                                                   1243 non-null   object
# ...

# %% [markdown]
# ChatGPT Prompt: beri kode untuk mendapatkan summary statistical dari dataframe

# %%
# Mendapatkan summary statistical dari dataframe
df.describe()
# Out:
#                Age  Total years of experience  Years of experience in Germany  \
# count  1226.000000                1230.000000                     1194.000000
# mean     32.509788                   9.078130                        3.757956
# std       5.663804                  11.901317                        3.656551
# min      20.000000                   0.000000                        0.000000
# 25%      29.000000                   5.000000                        1.000000
# 50%      32.000000                   8.000000                        3.000000
# 75%      35.000000                  12.000000                        5.000000
# max      69.000000                 383.000000                       30.000000
#
#        Yearly brutto salary (without bonus and stocks) in EUR  \
# count                                       1.253000e+03
# mean                                        8.027904e+07
# std                                         2.825061e+09
# ...

# %% [markdown]
# Beri kode untuk memperbarui nama-nama fitur berikut:
#
# * Total years of experience -> Total experience
# * Years of experience in Germany -> Experience in Germany
# * Your main technology / programming language -> Main programming language
# * Other technologies/programming languages you use often -> Other programming languages
# * Yearly brutto salary (without bonus and stocks) in EUR -> Yearly brutto salary
# * Yearly bonus + stocks in EUR -> Yearly bonus and stocks
# * Annual brutto salary (without bonus and stocks) one year ago. Only answer if
# * staying in the same country -> Previous yearly brutto salary
# * Annual bonus+stocks one year ago. Only answer if staying in same country -> Previous yearly bonus and stocks
# * Number of vacation days -> Vacation days
# * Main language at work -> Main work language
# * Have you lost your job due to the coronavirus outbreak? -> Lost job due to COVID-19
# * Have you been forced to have a shorter working week (Kurzarbeit)? If yes, how many hours per week -> Kurzarbeit hours per week
# * Have you received additional monetary support from your employer due to Work From Home? If yes, how much in 2020 in EUR -> Additional monetary support in 2020

# %%
# Dictionary yang berisi pasangan nama lama dan nama baru
new_column_names = {
    "Total years of experience": "Total experience",
    "Years of experience in Germany": "Experience in Germany",
    "Your main technology / programming language": "Main programming language",
    "Other technologies/programming languages you use often": "Other programming languages",
    "Yearly brutto salary (without bonus and stocks) in EUR": "Yearly brutto salary",
    "Yearly bonus + stocks in EUR": "Yearly bonus and stocks",
    "Annual brutto salary (without bonus and stocks) one year ago. Only answer if staying in the same country": "Previous yearly brutto salary",
    "Annual bonus+stocks one year ago. Only answer if staying in same country": "Previous yearly bonus and stocks",
    "Number of vacation days": "Vacation days",
    "Main language at work": "Main work language",
    "Have you lost your job due to the coronavirus outbreak?": "Lost job due to COVID-19",
    "Have you been forced to have a shorter working week (Kurzarbeit)? If yes, how many hours per week": "Kurzarbeit hours per week",
    "Have you received additional monetary support from your employer due to Work From Home? If yes, how much in 2020 in EUR": "Additional monetary support in 2020"
}

# Memperbarui nama kolom dalam dataframe
df = df.rename(columns=new_column_names)

# Menampilkan 5 baris teratas setelah nama kolom diperbarui
print(df.head())
# Out:
#              Timestamp   Age Gender    City           Position   \
# 0  24/11/2020 11:14:15  26.0   Male  Munich   Software Engineer
# 1  24/11/2020 11:14:16  26.0   Male  Berlin   Backend Developer
# 2  24/11/2020 11:14:21  29.0   Male  Berlin   Software Engineer
# 3  24/11/2020 11:15:24  28.0   Male  Berlin  Frontend Developer
# 4  24/11/2020 11:15:46  37.0   Male  Berlin   Backend Developer
#
#    Total experience  Experience in Germany Seniority level  \
# 0               5.0                    3.0          Senior
# 1               7.0                    4.0          Senior
# 2              12.0                    6.0            Lead
# 3               4.0                    1.0          Junior
# 4              17.0                    6.0          Senior
#
#   Main programming language      Other programming languages  ...  \
# 0                TypeScript  Kotlin, Javascript / Typescript  ...
# 1                      Ruby                              NaN  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1253 entries, 0 to 1252
# Data columns (total 23 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Timestamp                            1253 non-null   object
#  1   Age                                  1226 non-null   float64
#  2   Gender                               1243 non-null   object
#  3   City                                 1253 non-null   object
#  4   Position                             1247 non-null   object
#  5   Total experience                     1230 non-null   float64
#  6   Experience in Germany                1194 non-null   float64
#  7   Seniority level                      1241 non-null   object
#  8   Main programming language            1126 non-null   object
#  9   Other programming languages          1096 non-null   object
#  10  Yearly brutto salary                 1253 non-null   float64
# ...

# %% [markdown]
# ChatGPT Prompt: beri baris untuk menampilkan baris yang meiliki null value

# %%
# Menampilkan baris yang memiliki nilai null
null_rows = df[df.isnull().any(axis=1)]

# Menampilkan baris yang memiliki nilai null
null_rows
# Out:
#                 Timestamp   Age Gender         City  \
# 0     24/11/2020 11:14:15  26.0   Male       Munich
# 1     24/11/2020 11:14:16  26.0   Male       Berlin
# 2     24/11/2020 11:14:21  29.0   Male       Berlin
# 3     24/11/2020 11:15:24  28.0   Male       Berlin
# 4     24/11/2020 11:15:46  37.0   Male       Berlin
# ...                   ...   ...    ...          ...
# 1247  18/01/2021 11:50:02  34.0   Male       Zurich
# 1248  18/01/2021 15:05:50  31.0   Male       Berlin
# 1249  18/01/2021 17:46:02  33.0   Male       Berlin
# 1250  18/01/2021 23:20:35  39.0   Male       Munich
# 1251  19/01/2021 10:17:58  26.0   Male  Saarbrücken
#
#                                    Position   Total experience  \
# 0                          Software Engineer               5.0
# 1                          Backend Developer               7.0
# 2                          Software Engineer              12.0
# 3                         Frontend Developer               4.0
# ...

# %% [markdown]
# ChatGPT Prompt: beri kode untuk mengisi baris dari fitur "Kurzabeit hours per week" yang memiliki null value dengan nilai ''0"

# %%
# Mengisi null value pada kolom "Kurzarbeit hours per week" dengan nilai "0"
df['Kurzarbeit hours per week'] = df['Kurzarbeit hours per week'].fillna(0)

# Menampilkan 5 baris teratas setelah pengisian nilai null
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1253 entries, 0 to 1252
# Data columns (total 23 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Timestamp                            1253 non-null   object
#  1   Age                                  1226 non-null   float64
#  2   Gender                               1243 non-null   object
#  3   City                                 1253 non-null   object
#  4   Position                             1247 non-null   object
#  5   Total experience                     1230 non-null   float64
#  6   Experience in Germany                1194 non-null   float64
#  7   Seniority level                      1241 non-null   object
#  8   Main programming language            1126 non-null   object
#  9   Other programming languages          1096 non-null   object
#  10  Yearly brutto salary                 1253 non-null   float64
# ...

# %% [markdown]
# ChatGPT Prompt: beri mode untuk menampilkan pie diagram chart untuk fitur age dengan min 20, max 69

# %%
# @title 5. Visualisasikan Data

import matplotlib.pyplot as plt

# Menentukan rentang nilai umur
min_age = 20
max_age = 69


# Mengelompokkan data umur ke dalam kategori
bins = [min_age, 30, 40, 50, 60, max_age]
labels = ['20-30', '31-40', '41-50', '51-60', '61+']

# Mengelompokkan data umur ke dalam kategori
df['Age_group'] = pd.cut(df['Age'], bins=bins, labels=labels, right=False)

# Menghitung jumlah data dalam setiap kategori
age_counts = df['Age_group'].value_counts()

# Membuat pie chart untuk umut
plt.figure(figsize=(8, 6))
plt.pie(age_counts, labels=age_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribusi Usia (20-69 tahun)')
plt.axis('equal')  # Membuat lingkaran menjadi sejati
plt.show()

# %% [markdown]
# ChatGPT Prompt: beri kode untuk menampilkan baris data yang memiliki Age '51-60', '60+'

# %%
# Menampilkan baris data yang memiliki Age '51-60' atau '60+'
filtered_data = df.loc[df['Age_group'].isin(['51-60', '60+'])]

# Menampilkan baris data yang telah difilter
filtered_data
# Out:
#                 Timestamp   Age Gender        City           Position   \
# 23    24/11/2020 11:23:11  59.0   Male      Berlin   Backend Developer
# 232   24/11/2020 13:53:01  56.0   Male  Ingolstadt   Software Engineer
# 233   24/11/2020 13:54:47  53.0   Male   Stuttgart  Frontend Developer
# 403   24/11/2020 19:48:24  50.0   Male      Berlin   Software Engineer
# 673   25/11/2020 18:56:02  51.0   Male      Berlin   Software Engineer
# 955   30/11/2020 12:56:08  54.0   Male      Milano              Sales
# 1159  14/12/2020 08:55:24  56.0   Male      Munich   Software Engineer
# 1182  20/12/2020 01:48:34  54.0   Male      Munich   Software Engineer
# 1232  08/01/2021 16:12:36  52.0   Male   Stuttgart   Software Engineer
#
#       Total experience  Experience in Germany Seniority level  \
# 23                30.0                   30.0          Senior
# 232                9.0                    9.0          Senior
# 233               15.0                   15.0          Senior
# ...

# %%
import matplotlib.pyplot as plt

# Memberikan nilai numerik kepada setiap kategori gender
gender_mapping = {'Male': 0, 'Female': 1}
df['Gender_Code'] = df['Gender'].map(gender_mapping)

# Membuat histogram untuk kolom gender yang sudah dikodekan
plt.hist(df['Gender_Code'], bins=2, color='skyblue', edgecolor='black')
plt.xlabel('Gender')
plt.ylabel('Frequency')
plt.title('Histogram of Gender')
plt.xticks(range(2), ['Male', 'Female'])
plt.grid(True)
plt.show()

# %%
import seaborn as sns

# Menghitung korelasi antar fitur numerik dalam DataFrame
correlation_matrix = df.corr()

# Membuat heatmap korelasi
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Heatmap Korelasi Antar Fitur')
plt.show()
# Out:
# <ipython-input-97-4ad629e72290>:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()
